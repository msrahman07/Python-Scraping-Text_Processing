# %%
import requests
from bs4 import BeautifulSoup
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
nltk.download('punkt')
nltk.download('stopwords')
from collections import Counter
    
URL = "https://www.geeksforgeeks.org/data-structures/"
req = requests.get(URL)
#print(req.content)
soup = BeautifulSoup(req.content, 'html5lib')
#print(soup.prettify())
# Out:
# [nltk_data] Downloading package punkt to /home/shahriar/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/shahriar/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# Out:
# <Response [200]>

# %%
def process_html(url):
    req = requests.get(url)
    html = req.content
    soup = BeautifulSoup(html, "html.parser")
    
    for data in soup(['style', 'script']):
        data.decompose()
        
    return ' '.join(soup.stripped_strings)

# %%
text = process_html("https://goodle.com")
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# ~/anaconda3/lib/python3.8/site-packages/urllib3/contrib/pyopenssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname)
#     487             try:
# --> 488                 cnx.do_handshake()
#     489             except OpenSSL.SSL.WantReadError:
#
# ~/anaconda3/lib/python3.8/site-packages/OpenSSL/SSL.py in do_handshake(self)
#    1827         result = _lib.SSL_do_handshake(self._ssl)
# -> 1828         self._raise_ssl_error(self._ssl, result)
#    1829
#
# ~/anaconda3/lib/python3.8/site-packages/OpenSSL/SSL.py in _raise_ssl_error(self, ssl, result)
#    1565         else:
# -> 1566             _raise_current_error()
#    1567
#
# ~/anaconda3/lib/python3.8/site-packages/OpenSSL/_util.py in exception_from_error_queue(exception_type)
#      56
# ---> 57     raise exception_type(errors)
#      58
#
# Error: [('SSL routines', 'ssl3_read_bytes', '')]
#
# During handling of the above exception, another exception occurred:
#
# SSLError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     669             # Make the request on the httplib connection object.
# --> 670             httplib_response = self._make_request(
#     671                 conn,
#
# ~/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     380         try:
# --> 381             self._validate_conn(conn)
#     382         except (SocketTimeout, BaseSSLError) as e:
#
# ~/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#     977         if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# --> 978             conn.connect()
#     979
#
# ~/anaconda3/lib/python3.8/site-packages/urllib3/connection.py in connect(self)
#     361
# --> 362         self.sock = ssl_wrap_socket(
#     363             sock=conn,
#
# ~/anaconda3/lib/python3.8/site-packages/urllib3/util/ssl_.py in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data)
#     385         if HAS_SNI and server_hostname is not None:
# --> 386             return context.wrap_socket(sock, server_hostname=server_hostname)
#     387
#
# ~/anaconda3/lib/python3.8/site-packages/urllib3/contrib/pyopenssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname)
#     493             except OpenSSL.SSL.Error as e:
# --> 494                 raise ssl.SSLError("bad handshake: %r" % e)
#     495             break
#
# SSLError: ("bad handshake: Error([('SSL routines', 'ssl3_read_bytes', '')])",)
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# ~/anaconda3/lib/python3.8/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#
# ~/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     725
# --> 726             retries = retries.increment(
#     727                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#
# ~/anaconda3/lib/python3.8/site-packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     445         if new_retry.is_exhausted():
# --> 446             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     447
#
# MaxRetryError: HTTPSConnectionPool(host='goodle.com', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_read_bytes', '')])")))
#
# During handling of the above exception, another exception occurred:
#
# SSLError                                  Traceback (most recent call last)
# <ipython-input-113-87ebe046e991> in <module>
# ----> 1 text = process_html("https://goodle.com")
#
# <ipython-input-112-9288d5763647> in process_html(url)
#       1 def process_html(url):
# ----> 2     req = requests.get(url)
#       3     html = req.content
#       4     soup = BeautifulSoup(html, "html.parser")
#       5
#
# ~/anaconda3/lib/python3.8/site-packages/requests/api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# ~/anaconda3/lib/python3.8/site-packages/requests/api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# ~/anaconda3/lib/python3.8/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# ~/anaconda3/lib/python3.8/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# ~/anaconda3/lib/python3.8/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     512             if isinstance(e.reason, _SSLError):
#     513                 # This branch is for urllib3 v1.22 and later.
# --> 514                 raise SSLError(e, request=request)
#     515
#     516             raise ConnectionError(e, request=request)
#
# SSLError: HTTPSConnectionPool(host='goodle.com', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_read_bytes', '')])")))

# %%
def tokenzie_text(text):
    tokenizer = nltk.RegexpTokenizer(r"\w+")
    words = tokenizer.tokenize(text)
    stop_words = stopwords.words('english')
    removing_stop_words = [w for w in words if w not in stop_words]
    return removing_stop_words

# %%
num_words = {}
words = tokenzie_text(text)
counts = Counter(words)

# %%
for w in words:
    num_words[w] = counts[w]

# %%
num_words
# Out:
# {'Data': 34,
#  'Structures': 14,
#  'GeeksforGeeks': 4,
#  'Skip': 2,
#  'content': 3,
#  'Tutorials': 3,
#  'Practice': 15,
#  'DS': 2,
#  'Algo': 1,
#  'Must': 2,
#  'Do': 3,
#  'Questions': 4,
#  'DSA': 3,
#  'Topic': 2,
#  'wise': 13,
#  'Company': 4,
#  'Algorithms': 14,
#  'Analysis': 4,
#  'Asymptotic': 2,
#  'Worst': 1,
#  'Average': 1,
#  'Best': 2,
#  'Cases': 1,
#  'Notations': 1,
#  'Little': 1,
#  'little': 1,
#  'omega': 1,
#  'notations': 1,
#  'Lower': 1,
#  'Upper': 1,
#  'Bound': 2,
#  'Theory': 2,
#  'Loops': 1,
#  'Solving': 1,
#  'Recurrences': 1,
#  'Amortized': 1,
#  'What': 3,
#  'Space': 3,
#  'Complexity': 4,
#  'mean': 1,
#  'Pseudo': 1,
#  'polynomial': 1,
#  'Polynomial': 1,
#  'Time': 6,
#  'Approximation': 1,
#  'Scheme': 1,
#  'A': 26,
#  'Question': 2,
#  'Searching': 3,
#  'Sorting': 7,
#  'Graph': 30,
#  'Pattern': 1,
#  'Geometric': 1,
#  'Mathematical': 1,
#  'Bitwise': 1,
#  'Randomized': 2,
#  'Greedy': 1,
#  'Dynamic': 2,
#  'Programming': 7,
#  'Divide': 1,
#  'Conquer': 1,
#  'Backtracking': 1,
#  'Branch': 1,
#  'All': 20,
#  'Arrays': 7,
#  'Linked': 79,
#  'List': 80,
#  'Stack': 29,
#  'Queue': 27,
#  'Binary': 72,
#  'Tree': 131,
#  'Search': 40,
#  'Heap': 29,
#  'Hashing': 22,
#  'Advanced': 7,
#  'Structure': 19,
#  'Matrix': 14,
#  'Strings': 1,
#  'Interview': 7,
#  'Corner': 1,
#  'Preparation': 4,
#  'Top': 4,
#  'Topics': 4,
#  'Experiences': 1,
#  'Experienced': 1,
#  'Interviews': 2,
#  'Internship': 3,
#  'Competititve': 2,
#  'Design': 10,
#  'Patterns': 3,
#  'System': 5,
#  'Tutorial': 3,
#  'Multiple': 1,
#  'Choice': 1,
#  'Quizzes': 2,
#  'Languages': 2,
#  'C': 17,
#  'Java': 9,
#  'Python': 10,
#  'JavaScript': 3,
#  'jQuery': 2,
#  'SQL': 2,
#  'PHP': 2,
#  'Scala': 1,
#  'Perl': 1,
#  'Go': 1,
#  'Language': 4,
#  'HTML': 3,
#  'CSS': 3,
#  'Kotlin': 1,
#  'CS': 14,
#  'Subjects': 2,
#  'Mathematics': 2,
#  'Operating': 1,
#  'DBMS': 1,
#  'Computer': 3,
#  'Networks': 1,
#  'Organization': 1,
#  'Architecture': 1,
#  'Computation': 1,
#  'Compiler': 1,
#  'Digital': 1,
#  'Logic': 1,
#  'Software': 3,
#  'Engineering': 1,
#  'GATE': 7,
#  'Science': 1,
#  'Notes': 16,
#  'Last': 2,
#  'Minute': 1,
#  'Solved': 3,
#  'Papers': 5,
#  'Original': 2,
#  'Official': 2,
#  'Keys': 2,
#  '2021': 2,
#  'Dates': 1,
#  'Syllabus': 2,
#  'Important': 1,
#  'Web': 4,
#  'Technologies': 1,
#  'AngularJS': 1,
#  'ReactJS': 2,
#  'NodeJS': 1,
#  'Bootstrap': 2,
#  'Designs': 1,
#  'School': 4,
#  'Learning': 2,
#  'Number': 4,
#  'Algebra': 1,
#  'Trigonometry': 1,
#  'Statistics': 2,
#  'Probability': 1,
#  'Geometry': 1,
#  'Mensuration': 1,
#  'Calculus': 1,
#  'Maths': 11,
#  'Class': 23,
#  '8': 6,
#  '12': 5,
#  '9': 4,
#  '10': 5,
#  '11': 5,
#  'NCERT': 1,
#  'Solutions': 2,
#  'Solution': 10,
#  'RD': 1,
#  'Sharma': 1,
#  'Physics': 1,
#  'Exams': 1,
#  'PSUs': 1,
#  'ISRO': 4,
#  'Scientist': 1,
#  'Engineer': 1,
#  'Exam': 1,
#  'UGC': 4,
#  'NET': 4,
#  'Paper': 2,
#  'II': 1,
#  'III': 1,
#  'Student': 1,
#  'Campus': 4,
#  'Ambassador': 2,
#  'Program': 8,
#  'Project': 1,
#  'Geek': 3,
#  'Month': 2,
#  'Placement': 1,
#  'Course': 2,
#  'Testimonials': 1,
#  'Careers': 2,
#  'Jobs': 3,
#  'Apply': 1,
#  'Post': 1,
#  'Job': 1,
#  'JOB': 1,
#  'THON': 1,
#  'Events': 1,
#  'Courses': 8,
#  'Write': 7,
#  'Come': 2,
#  'write': 2,
#  'articles': 3,
#  'us': 2,
#  'get': 3,
#  'featured': 1,
#  'Learn': 3,
#  'code': 2,
#  'best': 3,
#  'industry': 2,
#  'experts': 2,
#  'Premium': 1,
#  'Get': 3,
#  'access': 2,
#  'ad': 1,
#  'free': 1,
#  'doubt': 1,
#  'assistance': 1,
#  'find': 2,
#  'dream': 2,
#  'job': 1,
#  'Geeks': 3,
#  'Digest': 1,
#  'Gblog': 1,
#  'Articles': 28,
#  'IDE': 1,
#  'Mantri': 1,
#  'Home': 1,
#  'Saved': 1,
#  'Videos': 1,
#  'GBlog': 1,
#  'Puzzles': 2,
#  'New': 2,
#  'Change': 1,
#  'Competitive': 2,
#  'Machine': 2,
#  'Development': 2,
#  'SDE': 2,
#  'Sheet': 2,
#  'GFG': 2,
#  'Projects': 1,
#  'Related': 1,
#  'Table': 4,
#  'Contents': 2,
#  'Array': 24,
#  'Introduction': 38,
#  'array': 43,
#  'rotation': 9,
#  'Reversal': 3,
#  'algorithm': 8,
#  'Block': 3,
#  'swap': 3,
#  'Rearrange': 4,
#  'arr': 10,
#  'program': 4,
#  'reverse': 3,
#  'string': 2,
#  'j': 6,
#  'even': 2,
#  'odd': 2,
#  'Set': 79,
#  '1': 44,
#  'vs': 5,
#  '2': 27,
#  'Inserting': 2,
#  'node': 10,
#  '3': 11,
#  'Deleting': 4,
#  'Delete': 8,
#  'given': 29,
#  'position': 3,
#  'Circular': 11,
#  'Applications': 16,
#  'Traversal': 13,
#  'Split': 3,
#  'two': 15,
#  'halves': 3,
#  'Sorted': 8,
#  'insert': 5,
#  'circular': 7,
#  'linked': 14,
#  'list': 13,
#  'STL': 2,
#  'Examples': 2,
#  'using': 20,
#  'Stacks': 3,
#  'Implement': 13,
#  'Special': 3,
#  'Added': 4,
#  'Optimized': 2,
#  'Version': 2,
#  'stacks': 4,
#  'Queues': 4,
#  'Implementation': 9,
#  'Priority': 6,
#  'Deque': 4,
#  'LRU': 3,
#  'Cache': 5,
#  'Properties': 4,
#  'Types': 4,
#  'Traversals': 5,
#  'Inorder': 15,
#  'Preorder': 5,
#  'Postorder': 2,
#  'without': 12,
#  'Recursion': 4,
#  'recursion': 6,
#  'stack': 7,
#  'Construct': 11,
#  'traversals': 5,
#  'tree': 8,
#  'Level': 3,
#  'order': 3,
#  'Complete': 4,
#  'Representation': 2,
#  'Insertion': 8,
#  'Advantages': 2,
#  'BST': 24,
#  'Hash': 3,
#  'preorder': 4,
#  'traversal': 5,
#  'Conversion': 4,
#  'Balanced': 8,
#  'Find': 22,
#  'minimum': 2,
#  'value': 3,
#  'building': 3,
#  'heap': 2,
#  'Binomial': 3,
#  'Fibonacci': 3,
#  'Leftist': 4,
#  'K': 8,
#  'ary': 2,
#  'HeapSort': 4,
#  'Iterative': 3,
#  'Index': 2,
#  'Mapping': 2,
#  'Trivial': 2,
#  'negatives': 2,
#  'allowed': 2,
#  'Separate': 3,
#  'Chaining': 3,
#  'Open': 3,
#  'Addressing': 3,
#  'Double': 2,
#  'Print': 10,
#  'Vertical': 3,
#  'Order': 5,
#  'Map': 2,
#  'based': 4,
#  'Method': 5,
#  'whether': 5,
#  'subset': 3,
#  'another': 5,
#  '5': 3,
#  'Union': 3,
#  'Intersection': 3,
#  'lists': 4,
#  'Given': 5,
#  'number': 8,
#  'x': 9,
#  'check': 4,
#  'pair': 5,
#  'sum': 8,
#  'aka': 2,
#  'Two': 5,
#  'Sum': 4,
#  'representations': 3,
#  'Breadth': 4,
#  'First': 8,
#  'BFS': 4,
#  'Depth': 5,
#  'DFS': 4,
#  'Detect': 10,
#  'Cycle': 6,
#  'Directed': 6,
#  'cycle': 3,
#  'undirected': 3,
#  'graph': 7,
#  'directed': 3,
#  'colors': 2,
#  'Topological': 7,
#  'Sorts': 2,
#  'Acyclic': 3,
#  'Kahn': 2,
#  'Rotate': 9,
#  'Elements': 2,
#  'Inplace': 3,
#  'rotate': 2,
#  'square': 4,
#  'matrix': 24,
#  '90': 6,
#  'degrees': 2,
#  'degree': 6,
#  'extra': 3,
#  'space': 3,
#  '180': 2,
#  'ring': 2,
#  'anticlockwise': 2,
#  'elements': 7,
#  'Turn': 2,
#  'image': 2,
#  'Check': 8,
#  'rows': 6,
#  'rotations': 2,
#  'Sort': 10,
#  'row': 8,
#  'maximum': 2,
#  '1s': 3,
#  'median': 2,
#  'sorted': 11,
#  'Memory': 15,
#  'efficient': 5,
#  'doubly': 5,
#  'XOR': 10,
#  'Efficient': 10,
#  'Doubly': 16,
#  'Updated': 2,
#  '31': 1,
#  'Jan': 1,
#  '2022': 2,
#  'data': 8,
#  'structure': 4,
#  'particular': 1,
#  'way': 1,
#  'organizing': 1,
#  'computer': 1,
#  'used': 1,
#  'effectively': 1,
#  'For': 1,
#  'example': 1,
#  'store': 1,
#  'items': 1,
#  'type': 1,
#  'This': 1,
#  'page': 1,
#  'contains': 2,
#  'detailed': 1,
#  'tutorials': 1,
#  'different': 2,
#  'structures': 1,
#  'topic': 1,
#  'problems': 2,
#  'Misc': 2,
#  'Overview': 4,
#  'Linear': 2,
#  'Trie': 6,
#  'Segment': 7,
#  'Suffix': 17,
#  'Abstract': 1,
#  'Singly': 2,
#  'Deletion': 5,
#  'key': 3,
#  'Programmer': 1,
#  'approach': 1,
#  'looking': 1,
#  'Length': 1,
#  'Recursive': 1,
#  'How': 6,
#  'functions': 1,
#  'modify': 1,
#  'head': 1,
#  'pointer': 1,
#  'Swap': 1,
#  'nodes': 4,
#  'swapping': 1,
#  'Reverse': 6,
#  'Merge': 6,
#  'Lists': 3,
#  'groups': 1,
#  'size': 7,
#  'Remove': 1,
#  'Loop': 1,
#  'Add': 1,
#  'numbers': 2,
#  'represented': 1,
#  'Generic': 1,
#  'The': 2,
#  'Great': 1,
#  'Problem': 3,
#  'QuickSort': 1,
#  'Quiz': 14,
#  'Coding': 13,
#  'Recent': 11,
#  'Infix': 1,
#  'Postfix': 2,
#  'Evaluation': 1,
#  'Expression': 2,
#  'String': 1,
#  'balanced': 1,
#  'parentheses': 1,
#  'expression': 1,
#  'Next': 1,
#  'Greater': 1,
#  'Element': 3,
#  'Stock': 2,
#  'Span': 1,
#  'operations': 2,
#  'middle': 1,
#  'element': 4,
#  'efficiently': 2,
#  'implement': 2,
#  'k': 9,
#  'single': 2,
#  'first': 1,
#  'tour': 1,
#  'visits': 1,
#  'petrol': 1,
#  'pumps': 1,
#  'Maximum': 6,
#  'subarrays': 1,
#  'An': 2,
#  'Interesting': 2,
#  'Generate': 1,
#  'Numbers': 1,
#  'n': 7,
#  'Handshaking': 1,
#  'Lemma': 1,
#  'Enumeration': 1,
#  'Diameter': 1,
#  'Threaded': 1,
#  'Height': 1,
#  'If': 1,
#  'sequences': 1,
#  'construct': 1,
#  'binary': 5,
#  'Clone': 1,
#  'Random': 1,
#  'Pointers': 1,
#  'width': 1,
#  'distance': 2,
#  'root': 1,
#  'Ancestors': 1,
#  'subtree': 1,
#  'Connect': 1,
#  'level': 1,
#  'Insert': 5,
#  'Minimum': 4,
#  'predecessor': 1,
#  'successor': 1,
#  'Lowest': 1,
#  'Common': 2,
#  'Ancestor': 1,
#  'Successor': 1,
#  'th': 2,
#  'smallest': 1,
#  'BSTs': 2,
#  'limited': 1,
#  'swapped': 1,
#  'correct': 1,
#  'Floor': 2,
#  'Ceil': 1,
#  'In': 2,
#  'place': 1,
#  'conversion': 1,
#  'DLL': 1,
#  'Total': 1,
#  'possible': 3,
#  'Trees': 5,
#  'keys': 2,
#  'Why': 1,
#  'Preferred': 1,
#  'Largest': 2,
#  'almost': 1,
#  'Tournament': 2,
#  'Winner': 2,
#  'Collision': 2,
#  'Handling': 2,
#  'duplicate': 2,
#  'within': 1,
#  'Itinerary': 1,
#  'tickets': 1,
#  'Employees': 1,
#  'Under': 1,
#  'every': 3,
#  'Employee': 1,
#  'Undirected': 1,
#  'Longest': 5,
#  'Path': 1,
#  'Bipartite': 1,
#  'Snake': 1,
#  'Ladder': 1,
#  'Minimize': 1,
#  'Cash': 1,
#  'Flow': 1,
#  'among': 1,
#  'set': 1,
#  'friends': 1,
#  'borrowed': 1,
#  'money': 1,
#  'Boggle': 1,
#  'words': 3,
#  'board': 1,
#  'characters': 1,
#  'Assign': 1,
#  'directions': 1,
#  'edges': 1,
#  'remains': 1,
#  'acyclic': 1,
#  'Shortest': 1,
#  'Paths': 1,
#  'Spanning': 1,
#  'Self': 3,
#  'Organizing': 1,
#  'Unrolled': 1,
#  'range': 1,
#  'Range': 4,
#  'Query': 1,
#  'Lazy': 1,
#  'Propagation': 1,
#  'Persistent': 1,
#  'prefix': 1,
#  'matching': 1,
#  'solution': 1,
#  'unique': 3,
#  'boolean': 3,
#  'DNS': 2,
#  'Look': 2,
#  'Up': 2,
#  'Forward': 1,
#  'Indexed': 6,
#  'Dimensional': 2,
#  'Fenwick': 1,
#  'Updates': 1,
#  'Point': 1,
#  'Queries': 2,
#  'Update': 1,
#  'nLogn': 1,
#  'Algorithm': 2,
#  'kasai': 1,
#  'Construction': 7,
#  'LCP': 1,
#  'Ukkonen': 6,
#  'Part': 6,
#  '4': 1,
#  '6': 1,
#  'Generalized': 1,
#  'Build': 1,
#  'Substring': 4,
#  'Repeated': 1,
#  'Palindromic': 1,
#  'AVL': 4,
#  'Splay': 3,
#  'B': 4,
#  'Red': 5,
#  'Black': 5,
#  'Balancing': 1,
#  'KD': 1,
#  'D': 2,
#  'Others': 1,
#  'Treap': 1,
#  'Ternary': 1,
#  'Interval': 1,
#  'stored': 1,
#  'machines': 1,
#  'frequent': 1,
#  'file': 1,
#  'sequence': 1,
#  'print': 1,
#  'anagrams': 1,
#  'together': 1,
#  'Decision': 1,
#  'Fake': 1,
#  'Counterfeit': 1,
#  'Coin': 2,
#  'Puzzle': 2,
#  'Spaghetti': 1,
#  'Dictionary': 1,
#  'Spell': 1,
#  'Checker': 1,
#  'Cartesian': 2,
#  'Sparse': 1,
#  'Centroid': 1,
#  'Decomposition': 1,
#  'Gomory': 1,
#  'Hu': 1,
#  'delete': 2,
#  'unsorted': 1,
#  'Leaders': 1,
#  'Majority': 1,
#  'Occurring': 1,
#  'Odd': 1,
#  'Times': 1,
#  'Contiguous': 1,
#  'Subarray': 1,
#  'Missing': 1,
#  'pivoted': 1,
#  'Median': 1,
#  'arrays': 1,
#  'adjacent': 1,
#  'frequency': 1,
#  'Count': 2,
#  'Inversions': 1,
#  'column': 3,
#  'spiral': 1,
#  'form': 1,
#  'Boolean': 1,
#  'sub': 2,
#  'M': 1,
#  'N': 1,
#  'transpose': 1,
#  '27': 1,
#  'rectangle': 1,
#  '2D': 1,
#  'Strassen': 1,
#  'Multiplication': 1,
#  'Create': 2,
#  'alternating': 1,
#  'rectangles': 1,
#  'O': 2,
#  'X': 1,
#  'squares': 1,
#  'islands': 1,
#  'island': 1,
#  'separated': 1,
#  'common': 1,
#  'Commonly': 1,
#  'Asked': 1,
#  'enriching': 1,
#  'course': 1,
#  'designed': 2,
#  'help': 2,
#  'crack': 1,
#  'coding': 2,
#  'interview': 2,
#  'top': 1,
#  'product': 1,
#  'service': 1,
#  'organizations': 1,
#  '200': 1,
#  'algorithmic': 1,
#  'premium': 1,
#  'lecture': 1,
#  'videos': 1,
#  'subject': 2,
#  'theoretical': 1,
#  'lifetime': 1,
#  'much': 1,
#  'Here': 1,
#  'prepared': 1,
#  'skill': 1,
#  'relevant': 1,
#  'core': 1,
#  'subjects': 1,
#  'programming': 4,
#  'language': 2,
#  'reasoning': 1,
#  'aptitude': 1,
#  'resume': 1,
#  'etc': 1,
#  'Live': 6,
#  'real': 1,
#  'time': 1,
#  'upskill': 1,
#  'company': 1,
#  'You': 2,
#  'attend': 1,
#  'live': 1,
#  'classes': 1,
#  'geographical': 1,
#  'location': 1,
#  'ask': 1,
#  'doubts': 1,
#  'instructor': 1,
#  'like': 1,
#  'offline': 1,
#  'classroom': 1,
#  'worthwhile': 1,
#  'Working': 1,
#  'Professionals': 1,
#  'Foundation': 5,
#  'JAVA': 1,
#  'scratch': 1,
#  'understand': 1,
#  'fundamental': 1,
#  'concepts': 1,
#  'strong': 1,
#  'foundation': 1,
#  'easiest': 1,
#  'manner': 1,
#  'These': 1,
#  'courses': 1,
#  'absolute': 1,
#  'beginners': 1,
#  'wish': 1,
#  'kickstart': 1,
#  'build': 1,
#  'foundations': 1,
#  'My': 1,
#  'Personal': 1,
#  'arrow_drop_up': 1,
#  'Save': 1,
#  'Writing': 1,
#  'comment': 1,
#  'Please': 1,
#  'use': 2,
#  'ide': 1,
#  'geeksforgeeks': 3,
#  'org': 2,
#  'generate': 1,
#  'link': 2,
#  'share': 1,
#  'Load': 1,
#  'Comments': 3,
#  'Old': 1,
#  'Summer': 1,
#  'Carnival': 1,
#  'View': 3,
#  'Details': 3,
#  'Paced': 1,
#  'Most': 2,
#  'Popular': 1,
#  'Buy': 1,
#  'Sell': 1,
#  'Product': 1,
#  'Based': 1,
#  'Companies': 1,
#  'Axios': 1,
#  'React': 1,
#  'Guide': 1,
#  'Beginners': 1,
#  'OpenCV': 1,
#  'waitKey': 1,
#  'Function': 1,
#  'Chrome': 1,
#  'Flags': 1,
#  'That': 1,
#  'Should': 1,
#  'Enable': 1,
#  'Visited': 1,
#  'Telegram': 1,
#  'Bot': 1,
#  'TabNet': 1,
#  'Flutter': 1,
#  'DropDownButton': 1,
#  'Widget': 1,
#  'Develop': 1,
#  'User': 1,
#  'Registration': 1,
#  'Form': 1,
#  'Appending': 1,
#  'dictionary': 1,
#  '5th': 1,
#  '118': 1,
#  'Sector': 1,
#  '136': 1,
#  'Noida': 1,
#  'Uttar': 1,
#  'Pradesh': 1,
#  '201305': 1,
#  'feedback': 1,
#  'About': 1,
#  'Us': 2,
#  'Media': 1,
#  'Contact': 1,
#  'Privacy': 2,
#  'Policy': 4,
#  'Copyright': 1,
#  'Cheat': 1,
#  'learning': 1,
#  'Video': 2,
#  'News': 2,
#  'Technology': 1,
#  'Work': 1,
#  'Career': 1,
#  'Business': 1,
#  'Finance': 1,
#  'Lifestyle': 1,
#  'CPP': 1,
#  'Golang': 1,
#  'Django': 1,
#  'Contribute': 1,
#  'Article': 2,
#  'Improve': 1,
#  'Pick': 1,
#  'Experience': 1,
#  'Internships': 1,
#  'Some': 1,
#  'rights': 1,
#  'reserved': 1,
#  'We': 1,
#  'cookies': 1,
#  'ensure': 1,
#  'browsing': 1,
#  'experience': 1,
#  'website': 1,
#  'By': 1,
#  'site': 1,
#  'acknowledge': 1,
#  'read': 1,
#  'understood': 1,
#  'Cookie': 1,
#  'Got': 1,
#  'It': 1,
#  'Start': 1,
#  'Your': 1,
#  'Journey': 1,
#  'Now': 1,
#  'Login': 1,
#  'Register': 1}
